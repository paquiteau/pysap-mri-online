# %% [markdown]
# # Brain data

# %%
DATA_DIR = "data/"
N_JOBS = 1
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from utils import implot, load_data
from online.metrics import crop_center_square
from mri.operators import FFT
from online.generators.column import PartialColumn2DKspaceGenerator, DataOnlyKspaceGenerator
from online.operators.fourier import ColumnFFT
# Out:
# /home/pac/gits/phd/pysap-mri/mri/operators/fourier/cartesian.py:34: UserWarning: pynufft python package has not been found. If needed use the master release. Till then you cannot use NUFFT on GPU
#   warnings.warn("pynufft python package has not been found. If needed use "
# /home/pac/gits/phd/pysap-mri/mri/operators/fourier/non_cartesian.py:42: UserWarning: gpuNUFFT python package has not been found. If needed please check on how to install in README
#   warnings.warn("gpuNUFFT python package has not been found. If needed "

# %%
_, real_img, mask_loc, final_mask = load_data(DATA_DIR,1)
mask_loc = np.arange(320)
real_img = np.complex128(real_img)
# real_img = np.zeros((320,320))
# real_img[130:190,130:190] = 1

implot(real_img)
full_k = sp.fft.ifftshift(sp.fft.fft2(sp.fft.fftshift(real_img)))
final_k = full_k

kspace_gen = PartialColumn2DKspaceGenerator(final_k, mask_loc)
kspace_gen2 = DataOnlyKspaceGenerator(final_k, mask_loc)

K_DIM = kspace_gen.shape[-2:]
N_COILS = 1

fourier_op = FFT(mask=kspace_gen.mask,
                 shape=K_DIM,
                 n_coils=N_COILS,
                 n_jobs=N_JOBS)
line_fourier_op = ColumnFFT(shape=K_DIM,
                          n_coils=N_COILS,
                          line_index=0)

idx = 32 # the discrete frequency line to acquire.
# Out:
# (16, 640, 320) complex128
# (320, 320) float32
# file_brain_AXFLAIR_200_6002462.h5
# 1

# %%
# %%time
k, mask = kspace_gen[idx]
f = kspace_gen.cols[idx]
fourier_op.mask = mask
fftmask  = fourier_op.op(real_img)[:,f]
# Out:
# CPU times: user 0 ns, sys: 8.36 ms, total: 8.36 ms
# Wall time: 5.9 ms

# %%
# %%time
k,f = kspace_gen2[idx]
line_fourier_op.line_index = f
fft_line = line_fourier_op.op(real_img)
# Out:
# CPU times: user 6.5 ms, sys: 0 ns, total: 6.5 ms
# Wall time: 2.82 ms

# %%
plt.figure()
plt.plot(abs(fftmask-fft_line))
plt.title("absolute error, forward operator")
# Out:
# Text(0.5, 1.0, 'absolute error, forward operator')

# %%
ifftmask = fourier_op.adj_op(fourier_op.op(real_img))
ifft_line = line_fourier_op.adj_op(line_fourier_op.op(real_img))
ifft_line2 = line_fourier_op.auto_adj_op(real_img)

implot(np.concatenate([ifftmask,ifft_line, ifft_line],axis=1),colorbar=True)
implot(abs(ifftmask-ifft_line),colorbar=True)
implot(abs(ifft_line-ifft_line2),colorbar=True)

# %%
peak_err = np.zeros(320)
for idx in range(len(peak_err)):
    # fft2
    _, mask = kspace_gen[idx]
    f = kspace_gen.cols[idx]
    fourier_op.mask = mask
    fftmask  = fourier_op.op(real_img)[:,f]
    #fft1.5
    _, f = kspace_gen2[idx]
    line_fourier_op.line_index = f
    linefft = line_fourier_op.op(real_img)
    peak_err[idx] = 100 * np.max(np.nan_to_num(np.abs((linefft-fftmask)/fftmask)))

# %%
plt.semilogy(peak_err,'-*')
plt.title('peak % error between FFT2D+mask and FFT1.5D')
plt.xlabel('mask column (starting from center')
# Out:
# Text(0.5, 0, 'mask column (starting from center')

# %%
peak_err2 = np.zeros(320)
for idx in range(len(peak_err2)):
    # fft2
    _, mask = kspace_gen[idx]
    f = kspace_gen.cols[idx]
    fourier_op.mask = mask
    ifftmask  = fourier_op.adj_op(fourier_op.op(real_img))
    #fft1.5
    _, f = kspace_gen2[idx]
    line_fourier_op.line_index = f
    ilinefft = line_fourier_op.adj_op(line_fourier_op.op(real_img))
    peak_err2[idx] = 100 * np.max(np.nan_to_num(np.abs((ilinefft-ifftmask)/ifftmask)))

# %%
plt.semilogy(peak_err2,'-*')
plt.title('peak % error for IFFT(FFT(x))')
plt.xlabel('mask column (Center = null frequency)')
# Out:
# Text(0.5, 0, 'mask column (Center = null frequency)')

# %% [markdown]
# ## How does it scale
# ### Forward operator

# %%
import time
sizes = 64 * np.arange(1,17)
times1 = np.zeros((len(sizes),2))
for n,size in enumerate(sizes):
    ta = 0
    tb = 0
    K_DIM = (size,size)
    mask = np.zeros(K_DIM)
    mask[:,size//2] = 1
    line_fourier_op = ColumnFFT(shape=K_DIM,
                          n_coils=N_COILS,
                          line_index=size//2)
    fourier_op = FFT(mask=mask,
                 shape=K_DIM,
                 n_coils=N_COILS,
                 n_jobs=N_JOBS)
    for k in range(5):
        real_img = np.random.random(K_DIM) + 1j *np.random.random(K_DIM)
        ts = time.perf_counter()
        _ = fourier_op.op(real_img)
        ti = time.perf_counter()
        _ = line_fourier_op.op(real_img)
        tf = time.perf_counter()
        ta += ti-ts
        tb += tf-ti
    times1[n,0] = ta/5
    times1[n,1] = tb/5

# %%
plt.plot(sizes[1:],times1[1:,0],label="FFT2D+mask")
plt.plot(sizes[1:],times1[1:,1],label="FFT1.5D")
plt.legend()
plt.xlabel('resolution')
plt.ylabel('time')
# Out:
# Text(0, 0.5, 'time')

# %% [markdown]
# ### Backward operator

# %%
sizes = 64 * np.arange(1,17)
times2 = np.zeros((len(sizes),2))
for n,size in enumerate(sizes):
    ta = 0
    tb = 0
    K_DIM = (size,size)
    mask = np.zeros(K_DIM)
    mask[:,size//2] = 1
    line_fourier_op = ColumnFFT(shape=K_DIM,
                      n_coils=N_COILS,
                      line_index=size//2)
    fourier_op = FFT(mask=mask,
             shape=K_DIM,
             n_coils=N_COILS,
             n_jobs=N_JOBS)
    for k in range(5):
        k_ref = np.random.random(K_DIM) + 1j *np.random.random(K_DIM)
        k_ref_mask = k_ref[:,size//2]
        ts = time.perf_counter()
        _ = fourier_op.adj_op(k_ref)
        ti = time.perf_counter()
        _ = line_fourier_op.adj_op(k_ref_mask)
        tf = time.perf_counter()
        ta += ti-ts
        tb += tf-ti
    times2[n,0] = ta/5
    times2[n,1] = tb/5

# %%
plt.plot(sizes[1:],times2[1:,0],label="IFFT2D+mask")
plt.plot(sizes[1:],times2[1:,1],label="IFFT1.5D")
plt.legend()
plt.xlabel('resolution')
plt.ylabel('time')
# Out:
# Text(0, 0.5, 'time')

# %% [markdown]
# ### Self-Adjoint operator

# %%
sizes = 64 * np.arange(1,17)
times3 = np.zeros((len(sizes),3))
for n,size in enumerate(sizes):
    ta = 0
    tb = 0
    tc = 0
    K_DIM = (size,size)
    mask = np.zeros(K_DIM)
    mask[:,size//2] = 1
    line_fourier_op = ColumnFFT(shape=K_DIM,
                      n_coils=N_COILS,
                      line_index=size//2)
    fourier_op = FFT(mask=mask,
             shape=K_DIM,
             n_coils=N_COILS,
             n_jobs=N_JOBS)
    for k in range(5):
        real_img = np.random.random(K_DIM) + 1j *np.random.random(K_DIM)
        ts = time.perf_counter()
        _ = fourier_op.adj_op(fourier_op.op(real_img))
        ti = time.perf_counter()
        _ = line_fourier_op.adj_op(line_fourier_op.op(real_img))
        tii = time.perf_counter()
        _ =  line_fourier_op.auto_adj_op(real_img)
        tf = time.perf_counter()
        ta += ti-ts
        tb += tii-ti
        tc += tf-tii
    times3[n,0] = ta/5
    times3[n,1] = tb/5
    times3[n,2] = tc/5

# %%
plt.plot(sizes,times3[:,0],label="IFFT2(FFT2D+mask)")
plt.plot(sizes,times3[:,1],label="IFFT1.5(FFT1.5D)")
plt.plot(sizes,times3[:,2],label="IFFT1.5(FFT1.5D)_faster")
plt.legend()
plt.xlabel('resolution')
plt.ylabel('time')

s=8
plt.figure()
plt.plot(sizes[:s],times3[:s,0],label="IFFT2(FFT2D+mask)")
plt.plot(sizes[:s],times3[:s,1],label="IFFT1.5(FFT1.5D)")
plt.plot(sizes[:s],times3[:s,2],label="IFFT1.5(FFT1.5D)_faster")
plt.legend()
plt.xlabel('resolution')
plt.ylabel('time')
# Out:
# Text(0, 0.5, 'time')
